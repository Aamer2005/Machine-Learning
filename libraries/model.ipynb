# %%
from sklearn.datasets import load_diabetes

data = load_diabetes()

import pandas as pd 

X = pd.DataFrame(data.data , columns=data.feature_names)

print(X.head(16))

y = pd.Series(data.target,name='target')
print(y.head(16))
# Out:
#          age       sex       bmi        bp        s1        s2        s3  \
# 0   0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1  -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2   0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3  -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4   0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5  -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6  -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7   0.063504  0.050680 -0.001895  0.066629  0.090620  0.108914  0.022869
# 8   0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9  -0.070900 -0.044642  0.039062 -0.033213 -0.012577 -0.034508 -0.024993
# 10 -0.096328 -0.044642 -0.083808  0.008101 -0.103389 -0.090561 -0.013948
# 11  0.027178  0.050680  0.017506 -0.033213 -0.007073  0.045972 -0.065491
# ...

# %%
X = pd.read_csv('salary.csv')
Y = X['purchased']

X = X.drop('purchased', axis=1)
print(X.head())
print(Y.head())
# Out:
#    age  salary  experience_years     city
# 0   25   30000                 1    Delhi
# 1   32   45000                 5   Mumbai
# 2   47   52000                20  Chennai
# 3   51   58000                24    Delhi
# 4   62   72000                30  Kolkata
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: purchased, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
X['city'] = label.fit_transform(X['city'])
print(X.head())
# Out:
#    age  salary  experience_years  city
# 0   25   30000                 1     1
# 1   32   45000                 5     3
# 2   47   52000                20     0
# 3   51   58000                24     1
# 4   62   72000                30     2

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X1 = scaler.fit_transform(X,Y)
print(X1)
# Out:
# [[-1.50741189 -1.7809083  -1.39314254 -0.53881591]
#  [-0.90098182 -0.59888952 -1.0061585   1.25723711]
#  [ 0.39851119 -0.04728075  0.44503164 -1.43684242]
#  [ 0.74504266  0.42552676  0.83201568 -0.53881591]
#  [ 1.6980042   1.52874429  1.41249174  0.3592106 ]
#  [-0.12128601  0.66193052 -0.0386984   1.25723711]
#  [-1.16088042 -1.07169703 -1.19965052 -1.43684242]
#  [-0.72771608 -0.75649202 -0.90941249 -0.53881591]
#  [ 1.09157413  1.29234054  1.21899972  0.3592106 ]
#  [ 0.48514406  0.34672551  0.63852366  1.25723711]]

# %%
from sklearn.model_selection import train_test_split

X_train , Y_train , X_test , Y_test = train_test_split(X1,Y,test_size=0.2)

print(X_train)
print(Y_train)
# Out:
# [[-1.50741189 -1.7809083  -1.39314254 -0.53881591]
#  [ 0.74504266  0.42552676  0.83201568 -0.53881591]
#  [ 1.6980042   1.52874429  1.41249174  0.3592106 ]
#  [ 0.48514406  0.34672551  0.63852366  1.25723711]
#  [-0.12128601  0.66193052 -0.0386984   1.25723711]
#  [-1.16088042 -1.07169703 -1.19965052 -1.43684242]
#  [ 0.39851119 -0.04728075  0.44503164 -1.43684242]
#  [-0.90098182 -0.59888952 -1.0061585   1.25723711]]
# [[-0.72771608 -0.75649202 -0.90941249 -0.53881591]
#  [ 1.09157413  1.29234054  1.21899972  0.3592106 ]]

# %%
print(Y)
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# 5    1
# 6    0
# 7    0
# 8    1
# 9    1
# Name: purchased, dtype: int64

# %%
import pandas as pd

# Load CSV (you already provided the data)
X = pd.read_csv('salary.csv')
print("Original Data:")
print(X)


# ------------------------------------
# 1. DROP THE 'purchased' COLUMN
# ------------------------------------
X = X.drop('purchased', axis=1)


# ------------------------------------
# 2. SEPARATE FEATURES AND TARGET
# ------------------------------------
Y = X['salary']              # Target
X = X.drop('salary', axis=1) # Remove target from features


# ------------------------------------
# 3. LABEL ENCODE THE CITY COLUMN
# ------------------------------------
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

X['city'] = label.fit_transform(X['city'])


# ------------------------------------
# 4. APPLY STANDARD SCALER TO AGE & EXPERIENCE
# ------------------------------------
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

X[['age', 'experience_years']] = sc.fit_transform(
    X[['age', 'experience_years']]
)


# ------------------------------------
# 5. TRAIN LINEAR REGRESSION MODEL
# ------------------------------------
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X, Y)
y_pred = model.predict(X)


# ------------------------------------
# Final Outputs
# ------------------------------------
print("\nProcessed X:")
print(X)

print("\nY values:")
print(Y)

from sklearn.metrics import mean_squared_error
acc  = mean_squared_error(Y,y_pred)
print(acc)
# Out:
# Original Data:
#    age  salary  experience_years     city  purchased
# 0   25   30000                 1    Delhi          0
# 1   32   45000                 5   Mumbai          1
# 2   47   52000                20  Chennai          1
# 3   51   58000                24    Delhi          1
# 4   62   72000                30  Kolkata          1
# 5   41   61000                15   Mumbai          1
# 6   29   39000                 3  Chennai          0
# 7   34   43000                 6    Delhi          0
# 8   55   69000                28  Kolkata          1
# 9   48   57000                22   Mumbai          1
#
# Processed X:
#         age  experience_years  city
# 0 -1.507412         -1.393143     1
# 1 -0.900982         -1.006158     3
# 2  0.398511          0.445032     0
# 3  0.745043          0.832016     1
# 4  1.698004          1.412492     2
# 5 -0.121286         -0.038698     3
# 6 -1.160880         -1.199651     0
# 7 -0.727716         -0.909412     1
# ...

# %%
from sklearn.metrics import confusion_matrix
y_true = [1, 0, 1, 1, 0, 1]
y_pred = [1, 0, 0, 1, 0, 1]

cm = confusion_matrix(y_true, y_pred)
print(cm)
# Out:
# [[2 0]
#  [1 3]]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# Sample data as list
data_list = [
    [25, 30000, 'Delhi', 0],
    [32, 45000, 'Mumbai', 1],
    [47, 52000, 'Chennai', 1],
    [51, 58000, 'Delhi', 1],
    [62, 72000, 'Kolkata', 1],
    [41, 61000, 'Mumbai', 1],
    [29, 39000, 'Chennai', 0],
    [34, 43000, 'Delhi', 0]
]

# Convert to DataFrame
df = pd.DataFrame(data_list, columns=['Age', 'Salary', 'City', 'Purchased'])

# Encode categorical column
df['City'] = LabelEncoder().fit_transform(df['City'])

# Split features and target
X = df.drop('Purchased', axis=1)
y = df['Purchased']

# Scale features
X = StandardScaler().fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Train model
model = LogisticRegression()
model.fit(X_train, y_train)

# Predict & Evaluate
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.5
# Confusion Matrix:
#  [[0 0]
#  [1 1]]
