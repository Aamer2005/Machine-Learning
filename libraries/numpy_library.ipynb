# %%
import numpy as np

# %%
arr = np.random.random((3,4))
arr
# Out:
# array([[0.89598023, 0.59735491, 0.34564375, 0.52573298],
#        [0.59507174, 0.12484291, 0.48135032, 0.47031629],
#        [0.65911465, 0.24270011, 0.20216152, 0.89009307]])

# %%
arr = np.random.randint(10,100,(4,5))
arr
# Out:
# array([[51, 58, 64, 47, 75],
#        [18, 35, 77, 98, 69],
#        [87, 36, 51, 76, 62],
#        [74, 30, 69, 75, 80]], dtype=int32)

# %%
d = np.linspace(10,20,3)
d
# Out:
# array([10., 15., 20.])

# %%
arr = np.arange(10,20,3)
arr
# Out:
# array([10, 13, 16, 19])

# %%
l = [1,2,3,4]

ar = np.asarray(l)
ar
# Out:
# array([1, 2, 3, 4])

# %%
arr = np.random.randint(1,50,(3,3))
print(arr.ndim)
print(arr.shape)
print(arr.size)
print(arr.dtype)
arr
# Out:
# 2
# (3, 3)
# 9
# int32
# array([[11, 30, 20],
#        [26, 13, 10],
#        [ 3, 15, 13]], dtype=int32)

# %%
l = [1,2,3] 
l2 = [4,5,6]
print(l+l2)

a = np.asarray(l)
b = np.asanyarray(l2)

print(a+b)
# Out:
# [1, 2, 3, 4, 5, 6]
# [5 7 9]

# %%
print(np.add(a,b))
print(np.subtract(a,b))
# Out:
# [5 7 9]
# [-3 -3 -3]

# %%
arr =  arr.T
arr
# Out:
# array([[11, 26,  3],
#        [30, 13, 15],
#        [20, 10, 13]], dtype=int32)

# %%
c = arr.reshape(9,1)
c
# Out:
# array([[11],
#        [26],
#        [ 3],
#        [30],
#        [13],
#        [15],
#        [20],
#        [10],
#        [13]], dtype=int32)

# %%
c = arr.reshape(9,)
c
# Out:
# array([11, 26,  3, 30, 13, 15, 20, 10, 13], dtype=int32)
