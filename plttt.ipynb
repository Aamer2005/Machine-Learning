# %%
import importlib

importlib.reload(plt)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6]
y = [1,4,9,16,25,36]
y2 = [1,4,9,9,4,1]

# %%
fig , axs = plt.subplots(2,2)

axs[0][0].plot(x,y,"r")
axs[0][0].scatter(x,y)
axs[1][0].plot(x,y,"g--")
axs[0][1].plot(x,y2)
axs[1][1].scatter(x,y)
axs[1][1].annotate("16",xy=(4,16),xytext=(5,19),
                   arrowprops=dict(facecolor = 'black',shrink=0.001))
plt.show()
